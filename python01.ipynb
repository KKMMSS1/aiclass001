# %% [markdown]
# <a href="https://colab.research.google.com/github/KKMMSS1/aiclass001/blob/main/python01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
print(a)
# Out:
# 10

# %% [markdown]
# 엑셀로 기준 하면 셀 1개

# %%
b=[10, 30, 44, 43]
print(b)
# Out:
# [10, 30, 44, 43]

# %% [markdown]
# 엑셀로 하면 행 또는 열 한줄

# %%
c=[[10, 20, 30],[15, 25, 35]]
print(c)
# Out:
# [[10, 20, 30], [15, 25, 35]]

# %% [markdown]
# 행과 열 총 드래그

# %%
import pandas as pd
df=pd. read_excel('data01.xlsx', header=None)
df
# Out:
#     0   1   2
# 0  10  20  30
# 1  40  50  60

# %% [markdown]
# 엑셀 데이터 가져오기
# header=None는 제목없이 데이터만 있을 때 확인하기 위해 작성했음

# %%
import pandas as pd
df=pd. read_csv('student.csv')
df
# Out:
#    height  weight
# 0    1.70      65
# 1    1.60      52
# 2    1.75      70
# 3    1.80      80

# %% [markdown]
# 그대로 작성하되 엑셀이 아닌 csv형식이다.
# 제목이 있기에 header는 작성 안했음.

# %%
import pandas as pd
df=pd. read_csv('student.csv')
df.shape
# Out:
# (4, 2)

# %% [markdown]
# 4행 2열임을 알수 있다.
# 제목은 데이터 값으로 취금하지 않음.

# %%
df. height
# Out:
# 0    1.70
# 1    1.60
# 2    1.75
# 3    1.80
# Name: height, dtype: float64

# %%
df. weight
# Out:
# 0    65
# 1    52
# 2    70
# 3    80
# Name: weight, dtype: int64

# %%
type(df.weight)
# Out:
# pandas.core.series.Series

# %% [markdown]
# series는 2차원으로 보면 됨.(리스트와 같다)

# %%
df['weight']
# Out:
# 0    65
# 1    52
# 2    70
# 3    80
# Name: weight, dtype: int64

# %% [markdown]
# 14열과 유사함. 데이터 불러오기 방식의 차이.
# 눈에 익혀둬

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  4 non-null      float64
#  1   weight  4 non-null      int64
# dtypes: float64(1), int64(1)
# memory usage: 192.0 bytes

# %% [markdown]
# 총 4개의 정보가 있다. 0에서 3까지
# 데이터 컬럼이 2개다. (키와 체중 의미)
#
# 컬럼은 키, 체중이다. 4개 값이 비었다.
# 하나는 실수, 하나는 정수이다.

# %%
import pandas as pd
df=pd. read_csv('Student_Marks.csv')
df.shape
# Out:
# (100, 3)

# %%
import pandas as pd
df=pd. read_csv('Student_Marks.csv')
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
import pandas as pd
df=pd. read_csv('Student_Marks.csv')
df.info
# Out:
# <bound method DataFrame.info of     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]>

# %% [markdown]
# df.info를 했을때 비어있는 데이터가 있는지를 찾아봐야한다. 이를 '결측치'라고 한다. (중요)

# %%
import pandas as pd
df=pd. read_csv('Student_Marks.csv')
df.describe()
# Out:
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %% [markdown]
# df.describe() 알아두기
# 합, 표준편차, 최하값, 최대값 등 파악 가능함.

# %%
df.isnull()
# Out:
#     number_courses  time_study  Marks
# 0            False       False  False
# 1            False       False  False
# 2            False       False  False
# 3            False       False  False
# 4            False       False  False
# ..             ...         ...    ...
# 95           False       False  False
# 96           False       False  False
# 97           False       False  False
# 98           False       False  False
# 99           False       False  False
#
# [100 rows x 3 columns]

# %% [markdown]
# df.isnull() 은 빈값이 있는냐 물어봄

# %%
df.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %% [markdown]
# df.isnull().sum() 은
# colume 별로 빈값이 있는지 물어봄.
